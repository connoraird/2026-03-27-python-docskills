# %%
# Analysing Patient Data

## libraries 
## read in data
## play with data

# %%
# librarier / packages
# !pip install numpy
import numpy

# %%
numpy.loadtxt(fname='inflammation-01.csv', delimiter = ',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 numpy.loadtxt(fname='inflammation-01.csv', delimiter = ',')
#
# File ~/work/python-docskills/2026-03-27-python-docskills/.venv/lib/python3.14/site-packages/numpy/lib/_npyio_impl.py:1384, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1381 if isinstance(delimiter, bytes):
#    1382     delimiter = delimiter.decode('latin1')
# -> 1384 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1385             converters=converters, skiplines=skiprows, usecols=usecols,
#    1386             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1387             max_rows=max_rows, quote=quotechar)
#    1389 return arr
#
# File ~/work/python-docskills/2026-03-27-python-docskills/.venv/lib/python3.14/site-packages/numpy/lib/_npyio_impl.py:1011, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1009     fname = os.fspath(fname)
#    1010 if isinstance(fname, str):
# -> 1011     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1012     if encoding is None:
#    1013         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/work/python-docskills/2026-03-27-python-docskills/.venv/lib/python3.14/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/work/python-docskills/2026-03-27-python-docskills/.venv/lib/python3.14/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: inflammation-01.csv not found.

# %%
import os
os.getcwd()
# Out:
# '/Users/connoraird/work/python-docskills/2026-03-27-python-docskills/swc-python'

# %%
data = numpy.loadtxt(fname='data/inflammation-01.csv', delimiter = ',')

# %%
help(numpy.amax)
# Out:
# Help on method descriptor amax in module numpy:
#
# amax(
#     a,
#     axis=None,
#     out=None,
#     keepdims=<no value>,
#     initial=<no value>,
#     where=<no value>
# )
#     Return the maximum of an array or maximum along an axis.
#
#     `amax` is an alias of `~numpy.max`.
#
#     See Also
#     --------
#     max : alias of this function
#     ndarray.max : equivalent method

# %%
data.shape
# Out:
# (60, 40)
