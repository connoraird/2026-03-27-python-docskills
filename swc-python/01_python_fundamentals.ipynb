# %%
weight_kg = 60

# %%
weight_kg
# Out:
# 60

# %%
weight_kg = 60.3
weight_kg
# Out:
# 60.3

# %%
patient_id = '001'
patient_id
# Out:
# '001'

# %%
weight_lb = weight_kg * 2.2
weight_lb
# Out:
# 132.66

# %%
patient_id = 'inflam_' + patient_id
patient_id
# Out:
# 'inflam_001'

# %%
import numpy

# %%
# %whos
# Out:
# Variable     Type      Data/Info
# --------------------------------
# numpy        module    <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# patient_id   str       inflam_001
# weight_kg    float     60.3
# weight_ky    int       60
# weight_lb    float     132.66
